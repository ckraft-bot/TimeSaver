# %%
import pandas as pd

unzipped_file = r"\\usfl04fsx04v.hsus.hsa.int\data\Contact Center Reporting\Data Sources\SJS Data - Deployments\Deployment_Dash_-_daily.xls"
cleaning = pd.read_excel(unzipped_file)
cleaning.head(6)
# Out:
#                           Service Job Status Report           Unnamed: 1  \
# 0  Service Job Date : From 08/01/2022 To 08/31/2022                  NaN
# 1                                               NaN                  NaN
# 2                                Service Job Number     Service Job Date
# 3                                               NaN                  NaN
# 4                       Manufacturer : HOMESERVE US                  NaN
# 5                                    SHMQ8301DCD5-1  2022-08-03 00:00:00
#
#                    Unnamed: 2                  Unnamed: 3  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2  Service Job Scheduled Date  New Scheduled Service Date
# 3                         NaN                         NaN
# 4                         NaN                         NaN
# 5         2022-08-04 00:00:00                         NaN
#
# ...

# %%
cleaning.shape
# Out:
# (25127, 55)

# %%
relevant = cleaning.drop(labels = [0,1,3,4], axis = 0)
relevant.head(5)
# Out:
#   Service Job Status Report           Unnamed: 1                  Unnamed: 2  \
# 2        Service Job Number     Service Job Date  Service Job Scheduled Date
# 5            SHMQ8301DCD5-1  2022-08-03 00:00:00         2022-08-04 00:00:00
# 6            SHMQ8303BAB0-2  2022-08-09 00:00:00         2022-08-10 00:00:00
# 7            SHMQ830102B9-2  2022-08-01 00:00:00         2022-08-02 00:00:00
# 8            SHMQ83045B62-1  2022-08-10 00:00:00         2022-08-10 00:00:00
#
#                    Unnamed: 3               Unnamed: 4       Unnamed: 5  \
# 2  New Scheduled Service Date  Actual Service Job Date  Slot Start Time
# 5                         NaN                      NaN             1200
# 6                         NaN                      NaN             0800
# 7                         NaN                      NaN             0800
# 8                         NaN                      NaN             1200
#
# ...

# %%
# make row 2 the header
relevant.columns = relevant.iloc[0]

new_header = relevant.iloc[1:].reset_index(drop=True)
new_header.head()
# Out:
# 2 Service Job Number     Service Job Date Service Job Scheduled Date  \
# 0     SHMQ8301DCD5-1  2022-08-03 00:00:00        2022-08-04 00:00:00
# 1     SHMQ8303BAB0-2  2022-08-09 00:00:00        2022-08-10 00:00:00
# 2     SHMQ830102B9-2  2022-08-01 00:00:00        2022-08-02 00:00:00
# 3     SHMQ83045B62-1  2022-08-10 00:00:00        2022-08-10 00:00:00
# 4     SHMQ83037EBD-2  2022-08-09 00:00:00        2022-08-11 00:00:00
#
# 2 New Scheduled Service Date Actual Service Job Date Slot Start Time  \
# 0                        NaN                     NaN            1200
# 1                        NaN                     NaN            0800
# 2                        NaN                     NaN            0800
# 3                        NaN                     NaN            1200
# 4                        NaN                     NaN            1600
#
# 2         Slot Length Service Job Status           Service Job Sub Status  \
# ...
